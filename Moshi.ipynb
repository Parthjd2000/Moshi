# %% [markdown]
# <a href="https://colab.research.google.com/github/Parthjd2000/Moshi/blob/main/Moshi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Tue Nov  4 17:07:33 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8              9W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install -U moshi gradio
# !python -m moshi.server --hf-repo kyutai/moshika-pytorch-bf16 --gradio-tunnel
# Out:
# ...
#   Using cached sphn-0.1.12-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.2 kB)
# ...
# Using cached sphn-0.1.12-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.8 MB)
# ...
#   Attempting uninstall: sphn
#     Found existing installation: sphn 0.2.0
#     Uninstalling sphn-0.2.0:
#       Successfully uninstalled sphn-0.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# moshi-mlx 0.3.0 requires sphn<0.3.0,>=0.2.0, but you have sphn 0.1.12 which is incompatible.
# ...
#   Using cached sphn-0.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.6 kB)
# ...
# Using cached sphn-0.2.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.4 MB)
# ...
#   Attempting uninstall: sphn
#     Found existing installation: sphn 0.1.12
#     Uninstalling sphn-0.1.12:
#       Successfully uninstalled sphn-0.1.12
# ...

# %%
# !python -m moshi.server --gradio-tunnel --hf-repo kyutai/moshika-pytorch-bf16
# Out:
# [Info] retrieving checkpoint
# /content/src/moshi/moshi/moshi/models/loaders.py:202: UserWarning: Repository kyutai/moshika-pytorch-bf16 contains no config.json. Assuming this is a Moshi 7B. Support for such repository might be removed in the future.
#   warnings.warn(
# [Info] loading mimi
# [Info] mimi loaded
# [Info] loading moshi
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/src/moshi/moshi/moshi/server.py", line 291, in <module>
#     main()
#   File "/content/src/moshi/moshi/moshi/server.py", line 237, in main
#     lm = checkpoint_info.get_moshi(device=args.device, dtype=args.dtype, fuse_lora=args.fuse_lora)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/src/moshi/moshi/moshi/models/loaders.py", line 298, in get_moshi
#     model = get_moshi_lm(
#             ^^^^^^^^^^^^^
# ...

# %%
# !git clone https://github.com/kyutai-labs/moshi.git
# %cd moshi
# Out:
# fatal: destination path 'moshi' already exists and is not an empty directory.
# /content/moshi

# %%
# !pip install -U pip setuptools wheel
# !pip install -U moshi
# optionally if you want the repo version:
# !pip install -U -e "git+https://github.com/kyutai-labs/moshi.git#egg=moshi&subdirectory=moshi"
# Out:
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# ...
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# ...
#   Using cached sphn-0.1.12-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.2 kB)
# ...
#   Using cached torch-2.7.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (29 kB)
# ...
#   Using cached nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# ...

# %%
# !python -m moshi.server --hf-repo kyutai/moshika-pytorch-bf16 --gradio-tunnel
# Out:
# [Info] retrieving checkpoint
# /content/moshi/src/moshi/moshi/moshi/models/loaders.py:202: UserWarning: Repository kyutai/moshika-pytorch-bf16 contains no config.json. Assuming this is a Moshi 7B. Support for such repository might be removed in the future.
#   warnings.warn(
# [Info] loading mimi
# [Info] mimi loaded
# [Info] loading moshi
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/moshi/src/moshi/moshi/moshi/server.py", line 291, in <module>
#     main()
#   File "/content/moshi/src/moshi/moshi/moshi/server.py", line 237, in main
#     lm = checkpoint_info.get_moshi(device=args.device, dtype=args.dtype, fuse_lora=args.fuse_lora)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/moshi/src/moshi/moshi/moshi/models/loaders.py", line 298, in get_moshi
#     model = get_moshi_lm(
# ...
